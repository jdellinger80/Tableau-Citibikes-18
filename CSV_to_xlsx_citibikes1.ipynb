# %%
import pandas as pd
import datetime
import numpy as np
from glob import glob
import os
import csv, os
from xlsxwriter.workbook import Workbook
from pathlib import Path

# %%
file_path = Path("2187-tripdata.csv")
df = pd.read_csv(file_path)
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           500  2018-07-01 00:33:51.2640  2018-07-01 00:42:12.0280
# 1           455  2018-07-01 02:06:54.0270  2018-07-01 02:14:29.0900
# 2          1080  2018-07-01 02:09:16.4640  2018-07-01 02:27:17.0290
# 3           632  2018-07-01 02:55:04.5870  2018-07-01 03:05:36.7910
# 4          1676  2018-07-01 03:24:27.4350  2018-07-01 03:52:23.7760
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id    end station name  \
# 0               -73.993929            3236  W 42 St & Dyer Ave
# ...

# %%
read_file = pd.read_csv (r'2187-tripdata.csv')
read_file.to_excel (r'2187tripdata.xlsx', index = None, header=True)

df.to_excel(r'tripdats.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/r6/rqxjkvw559lc0y5f5hmgvzg40000gp/T/ipykernel_20017/1650684641.py in <module>
#       1 read_file = pd.read_csv (r'2187-tripdata.csv')
# ----> 2 read_file.to_excel (r'2187tripdata.xlsx', index = None, header=True)
#       3
#       4 df.to_excel(r'tripdats.xlsx', index=False)
#       5
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2343             inf_rep=inf_rep,
#    2344         )
# -> 2345         formatter.write(
#    2346             excel_writer,
#    2347             sheet_name=sheet_name,
#
# ...

# %%
print("-------------------------------------------")
print(" .CSV to .XLSX Conversion Successful")
print("-------------------------------------------")
